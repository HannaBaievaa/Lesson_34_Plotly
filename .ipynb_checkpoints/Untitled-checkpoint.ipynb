# %%
import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in d:\projects_git\lesson_34_plotly\venv\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in d:\projects_git\lesson_34_plotly\venv\lib\site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
import numpy as np

# %%
avto = pd.read_excel("AVTO.xlsx")
avto
# Out:
#                         Марка авто  Вартість, грн  \
# 0      FIAT DUCATO 2.2 Multijet MT        1300000
# 1           PEUGEOT BOXER 335 L3H2        1150000
# 2         CITROEN JUMPER 4-35 L3H2        1314000
# 3           PEUGEOT BOXER 435 L4H2        1343000
# 4                 FIAT DUCATO L1H1        1210000
# 5          RANAULT MASTER L2H2 FWD        1146000
# 6         RENAULT MASTER L4H3 4500        1462000
# 7              FIAT FIORINO 1.4 MT         611000
# 8         RENAULT MASTER L2H2 3500        1146000
# 9   PEUGEOT PARTNER 1.5 L2 PREMIUM         952000
# 10         VOLKSWAGEN CADDY TDI MT        1018000
# 11     VOLKSWAGEN CRAFTER LR HD UH        1400000
# 12   MERCEDES-BENZ VITO 116 CDI MT        2258000
# 13             FORD TRANSIT MT 350        1645000
# 14          TOYOTA PROACE D-4D 6MT        1348000
# 15             RENAULT MASTER L1H1        1554000
# 16                 FIAT DUCATO LH2        1248000
# 17          HYUNDAI EX8 SUPER 3.9D        2218000
# 18            FORD TRANSIT MT R470        1864000
# 19            FORD TRANSIT MT F330        1554000
#
#     Споживання палива, л на 100 км  Макс швидкість, км/год  \
# 0                              7.3                     150
# 1                              7.5                     150
# 2                              8.7                     142
# 3                              7.5                     142
# 4                              6.4                     155
# 5                              8.7                     150
# 6                              8.7                     150
# 7                              6.4                     157
# 8                              8.7                     150
# 9                              4.5                     183
# 10                             4.5                     173
# 11                             8.5                     160
# 12                             6.4                     188
# 13                             6.8                     157
# 14                             5.9                     165
# 15                             8.7                     150
# 16                             7.3                     150
# 17                            13.0                     170
# 18                             7.5                     155
# 19                             6.9                     155
#
#     Вантажопідйомність, кг
# 0                     1450
# 1                     1640
# 2                     2107
# 3                     1900
# 4                     1640
# 5                     1732
# 6                     2052
# 7                      610
# 8                     1535
# 9                      931
# 10                     674
# 11                    1345
# 12                    1064
# 13                    1348
# 14                    1465
# 15                    1609
# 16                    1450
# 17                    5375
# 18                    2351
# 19                    1241

# %%
df_corr = avto.corr()
df_corr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_corr = avto.corr()
#       2 df_corr
#
# File D:\Projects_Git\Lesson_34_Plotly\venv\lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File D:\Projects_Git\Lesson_34_Plotly\venv\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File D:\Projects_Git\Lesson_34_Plotly\venv\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File D:\Projects_Git\Lesson_34_Plotly\venv\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: ' FIAT DUCATO 2.2 Multijet MT'

# %%
df= px.data.tips("avto")
